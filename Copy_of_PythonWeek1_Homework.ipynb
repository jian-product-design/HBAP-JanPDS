# %% [markdown]
# <a href="https://colab.research.google.com/github/jian-product-design/HBAP-JanPDS/blob/main/Copy_of_PythonWeek1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HBAP Summer Python 2024 - Week 1
#
# ### Homework
#
# ---

# %% [markdown]
# ### List all video urls, titles and views for 3blue1brown youtube channel

# %%
from bs4 import BeautifulSoup
import pandas as pd

from bs4 import BeautifulSoup

## Data from https://www.youtube.com/@3blue1brown/videos

threeblue1brown_html = '\n<!DOCTYPE html>\n<html>\n<head>\n<title>Video List</title>\n</head>\n<body>\n<h1>Python Summer 2024</h1>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Video Title</th>\n      <th>Video Link</th>\n      <th>View Count</th>\n      <th>source</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Attention in transformers, visually explained | Chapter 6, Deep Learning</td>\n      <td><a href="https://www.youtube.com/watch?v=eMlx5fFNoYc" target="_blank">https://www.youtube.com/watch?v=eMlx5fFNoYc</a></td>\n      <td>938585</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>But what is a GPT?  Visual intro to transformers | Chapter 5, Deep Learning</td>\n      <td><a href="https://www.youtube.com/watch?v=wjZofJX0v4M" target="_blank">https://www.youtube.com/watch?v=wjZofJX0v4M</a></td>\n      <td>2288443</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>4 questions about the refractive index | Optics puzzles 4</td>\n      <td><a href="https://www.youtube.com/watch?v=Cz4Q4QOuoo8" target="_blank">https://www.youtube.com/watch?v=Cz4Q4QOuoo8</a></td>\n      <td>676714</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>But why would light "slow down"? | Optics puzzles 3</td>\n      <td><a href="https://www.youtube.com/watch?v=KTzGBJPuJwM" target="_blank">https://www.youtube.com/watch?v=KTzGBJPuJwM</a></td>\n      <td>1198547</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>25 Math explainers you may enjoy | SoME3 results</td>\n      <td><a href="https://www.youtube.com/watch?v=6a1fLEToyvU" target="_blank">https://www.youtube.com/watch?v=6a1fLEToyvU</a></td>\n      <td>545317</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Explaining the barber pole effect from origins of light | Optics puzzles 2</td>\n      <td><a href="https://www.youtube.com/watch?v=aXRTczANuIs" target="_blank">https://www.youtube.com/watch?v=aXRTczANuIs</a></td>\n      <td>701802</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Polarized light in sugar water | Optics puzzles 1</td>\n      <td><a href="https://www.youtube.com/watch?v=QCX62YJCmGk" target="_blank">https://www.youtube.com/watch?v=QCX62YJCmGk</a></td>\n      <td>1002446</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>A pretty reason why Gaussian + Gaussian = Gaussian</td>\n      <td><a href="https://www.youtube.com/watch?v=d_qvLDhkg00" target="_blank">https://www.youtube.com/watch?v=d_qvLDhkg00</a></td>\n      <td>758503</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>This pattern breaks, but for a good reason | Moser\'s circle problem</td>\n      <td><a href="https://www.youtube.com/watch?v=YtkIWDE36qU" target="_blank">https://www.youtube.com/watch?v=YtkIWDE36qU</a></td>\n      <td>1885363</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>How They Fool Ya (live) | Math parody of Hallelujah</td>\n      <td><a href="https://www.youtube.com/watch?v=NOCsdhzo6Jg" target="_blank">https://www.youtube.com/watch?v=NOCsdhzo6Jg</a></td>\n      <td>953826</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th
td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>23</th>\n      <td>From Newton’s method to Newton’s fractal (which Newton knew nothing about)</td>\n      <td><a href="https://www.youtube.com/watch?v=-RdOwhmqP5s" target="_blank">https://www.youtube.com/watch?v=-RdOwhmqP5s</a></td>\n      <td>2783438</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>24</th>\n      <td>The Summer of Math Exposition</td>\n      <td><a href="https://www.youtube.com/watch?v=ojjzXyQCzso" target="_blank">https://www.youtube.com/watch?v=ojjzXyQCzso</a></td>\n      <td>721811</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>25</th>\n      <td>A quick trick for computing eigenvalues | Chapter 15, Essence of linear algebra</td>\n      <td><a href="https://www.youtube.com/watch?v=e50Bj7jn9IQ" target="_blank">https://www.youtube.com/watch?v=e50Bj7jn9IQ</a></td>\n      <td>983538</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>26</th>\n      <td>How (and why) to raise e to the power of a matrix | DE6</td>\n      <td><a href="https://www.youtube.com/watch?v=O85OWBJ2ayo" target="_blank">https://www.youtube.com/watch?v=O85OWBJ2ayo</a></td>\n      <td>2740543</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>27</th>\n      <td>The medical test paradox, and redesigning Bayes\' rule</td>\n      <td><a href="https://www.youtube.com/watch?v=lG4VkPoG3ko" target="_blank">https://www.youtube.com/watch?v=lG4VkPoG3ko</a></td>\n      <td>1202101</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>28</th>\n      <td>Hamming codes part 2: The one-line implementation</td>\n      <td><a href="https://www.youtube.com/watch?v=b3NxrZOu_CE" target="_blank">https://www.youtube.com/watch?v=b3NxrZOu_CE</a></td>\n      <td>835763</td>\n      <td>3blue1brown</td>\n    </tr>\n    <tr>\n      <th>29</th>\n      <td>But what are Hamming codes? The origin of error correction</td>\n      <td><a href="https://www.youtube.com/watch?v=X8jsijhllIA" target="_blank">https://www.youtube.com/watch?v=X8jsijhllIA</a></td>\n      <td>2339658</td>\n      <td>3blue1brown</td>\n    </tr>\n  </tbody>\n</table>\n</body>\n</html>\n'

# %% [markdown]
# #### A. Using BeautifulSoup

# %%
soup = BeautifulSoup(threeblue1brown_html, 'html.parser')

# %%
all_td = soup.find_all('td')

title_list = []
url_list = []

for i in range(0, len(all_td), 3):
    title_list.append(all_td[i].text)
    url_list.append(all_td[i+1].text)
    print(all_td[i].text, all_td[i+1].text)
# Out:
# Attention in transformers, visually explained | Chapter 6, Deep Learning https://www.youtube.com/watch?v=eMlx5fFNoYc
# 3blue1brown But what is a GPT?  Visual intro to transformers | Chapter 5, Deep Learning
# 2288443 3blue1brown
# https://www.youtube.com/watch?v=Cz4Q4QOuoo8 676714
# But why would light "slow down"? | Optics puzzles 3 https://www.youtube.com/watch?v=KTzGBJPuJwM
# 3blue1brown 25 Math explainers you may enjoy | SoME3 results
# 545317 3blue1brown
# https://www.youtube.com/watch?v=aXRTczANuIs 701802
# Polarized light in sugar water | Optics puzzles 1 https://www.youtube.com/watch?v=QCX62YJCmGk
# 3blue1brown A pretty reason why Gaussian + Gaussian = Gaussian
# 758503 3blue1brown
# https://www.youtube.com/watch?v=YtkIWDE36qU 1885363
# How They Fool Ya (live) | Math parody of Hallelujah https://www.youtube.com/watch?v=NOCsdhzo6Jg
# 3blue1brown Convolutions | Why X+Y in probability is a beautiful mess
# 632061 3blue1brown
# https://www.youtube.com/watch?v=cy8r7WSuT1I 1516920
# ...

# %%
# use beautful soup to parse the html and get the video titles, views and links

# %%
# to convert text to numeric
# df['View Count'] = df['View Count'].astype(int)

# %%
df = pd.DataFrame([title_list,url_list]).T
df.columns = ['Video Title', 'Video URL']
df
# Out:
#                                           Video Title  \
# 0   Attention in transformers, visually explained ...
# 1                                         3blue1brown
# 2                                             2288443
# 3         https://www.youtube.com/watch?v=Cz4Q4QOuoo8
# 4   But why would light "slow down"? | Optics puzz...
# 5                                         3blue1brown
# 6                                              545317
# 7         https://www.youtube.com/watch?v=aXRTczANuIs
# 8   Polarized light in sugar water | Optics puzzles 1
# 9                                         3blue1brown
# 10                                             758503
# 11        https://www.youtube.com/watch?v=YtkIWDE36qU
# 12  How They Fool Ya (live) | Math parody of Halle...
# 13                                        3blue1brown
# 14                                             632061
# 15        https://www.youtube.com/watch?v=cy8r7WSuT1I
# ...

# %% [markdown]
# #### B. Using Pandas

# %%
df.to_csv('habp_videos.csv', index =False)
dfs = pd.read_html(hbap_startups)

df = dfs[0][['Video Title', 'Video Link', 'source']]
df
## Number of rows and columns
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-79f0c2fabdfa> in <cell line: 2>()
#       1 df.to_csv('habp_videos.csv', index =False)
# ----> 2 dfs = pd.read_html(hbap_startups)
#       3
#       4 df = dfs[0][['Video Title', 'Video Link', 'source']]
#       5 df
#
# NameError: name 'hbap_startups' is not defined

# %%
df.sort_values(by=['Video Title'])
# Out:
#                                           Video Title  \
# 26                                           10319149
# 30                                            1428701
# 28             2021 Summer of Math Exposition results
# 2                                             2288443
# 18                                            2487770
# 22                                            3088160
# 25                                        3blue1brown
# 21                                        3blue1brown
# 17                                        3blue1brown
# 29                                        3blue1brown
# 13                                        3blue1brown
# 33                                        3blue1brown
# 9                                         3blue1brown
# 1                                         3blue1brown
# 37                                        3blue1brown
# 5                                         3blue1brown
# ...

# %%
df.sort_values(by=['Video Title']).reset_index(drop=True)
# Out:
#                                           Video Title  \
# 0                                            10319149
# 1                                             1428701
# 2              2021 Summer of Math Exposition results
# 3                                             2288443
# 4                                             2487770
# 5                                             3088160
# 6                                         3blue1brown
# 7                                         3blue1brown
# 8                                         3blue1brown
# 9                                         3blue1brown
# 10                                        3blue1brown
# 11                                        3blue1brown
# 12                                        3blue1brown
# 13                                        3blue1brown
# 14                                        3blue1brown
# 15                                        3blue1brown
# ...

# %% [markdown]
# ### C. Which video has highest view count ? (Display Video URL, title and number of views)

# %% [markdown]
# ### D. Average views for 3blue1brown ?

# %%
# Out:
# 2025741.3333333333
